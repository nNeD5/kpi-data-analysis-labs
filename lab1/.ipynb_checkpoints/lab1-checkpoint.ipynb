# %% [markdown]
# # Lab Work #1
# #### Nedozhdii Oleksii FF-31mn
#
# 1) Завантажити дані, вивести назви колонок і розмір датасета
# 2) Опрацювати пропуски (по можливості заповнити їх або видалити)
# 3) Візуалізувати дані: побудувати графік (heatmap), що відображає кореляції
# ознак між собою і з цільовою змінною (розміткою); побудувати гістограми
# розподілу ознак і boxplot-и ознак відносно цільової змінної (якщо ознак занадто багато
# обмежитися декількома)
# 4) Нормалізувати дані
# 5) Провести навчання наступних класифікаторів:
# - kNN
# - дерево ухвалення рішень
# - SVM
# - Random Forest
# - AdaBoost
#
# Підібрати оптимальні параметри
# - для kNN
# - для SVM за допомогою GridSearch підібрати оптимальні `C` і `gamma`
# - Серед обраних оптимальних моделей кожного класу вибрати найкращу.
# - Відобразити
# sklearn.metrics.classification_report і sklearn.metrics.confusion_matrix

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, GridSearchCV


plt.style.use("default")

# %% [markdown]
# ## Prepare data

# %%
df = pd.read_csv("OnlineNewsPopularity/OnlineNewsPopularity.csv", skipinitialspace=True)

# drop not useful(for now) data
df = df.drop(columns=["url", "timedelta", "weekday_is_monday",
                      "weekday_is_tuesday", "weekday_is_wednesday",
                      "weekday_is_thursday", "weekday_is_friday",
                      "weekday_is_saturday", "weekday_is_sunday",
                      "is_weekend", "shares", "LDA_00", "LDA_01",
                      "LDA_02", "LDA_03", "LDA_04"])

# choose target and features
features = df.columns.drop(labels=[
    "data_channel_is_lifestyle",
    "data_channel_is_entertainment",
    "data_channel_is_bus",
    "data_channel_is_socmed",
    "data_channel_is_tech",
    "data_channel_is_world",
])

# delete rows without target values
df = df[df[targets].any(axis=1)]

# check and drop null valus
null_indexes = sum(np.nonzero(pd.isnull(df)))
if len(null_indexes) > 0:
    print("Ups, spot null value. Going to drop it.")
    df = df.dropna()

# multiple columns data_channel_is_* -> one column with multiple values
labels = dict(zip(targets, ["Lifestyle", "Entertainment", "Business", "Social Media", "Tech", "World"]))
df["data_channel"] = df.apply(lambda row: [col for col in df.columns if row[col] and col.startswith("data_channel_")][0], axis=1)
for key in labels.keys():
    df.loc[df["data_channel"] == key, "data_channel"] = labels[key]
df = df.drop(columns=[col for col in df.columns if col.startswith("data_channel_is")])

# %% [markdown]
# ## Present data

# %%
df.info()
df.describe()

# %% [markdown]
# ## Features and target

# %%
target = "data_channel"
features = df.columns.drop(labels=target).to_list()
target_values = df["data_channel"].unique()

# %% [markdown]
# ### Calculate coor matrix

# %%
le = LabelEncoder()
df_encoded = df.copy()
df_encoded[target] = le.fit_transform(df[target])
corr_matrix = df_encoded.corr()
print(corr_matrix)
# Out:
#                               n_tokens_title  n_tokens_content  \
# n_tokens_title                      1.000000          0.020556
# n_tokens_content                    0.020556          1.000000
# n_unique_tokens                    -0.004753         -0.005331
# n_non_stop_words                   -0.004314          0.014529
# n_non_stop_unique_tokens           -0.004873         -0.002319
# num_hrefs                          -0.045392          0.465718
# num_self_hrefs                     -0.013441          0.297179
# num_imgs                            0.009149          0.401810
# num_videos                          0.061186          0.131991
# average_token_length               -0.065099          0.113963
# num_keywords                       -0.005877          0.089056
# kw_min_min                         -0.112958         -0.063818
# kw_max_min                         -0.010008          0.005368
# kw_avg_min                         -0.034094         -0.003424
# kw_min_max                          0.005977         -0.007081
# kw_max_max                          0.123070          0.070652
# kw_avg_max                          0.106702         -0.033906
# kw_min_avg                         -0.010187          0.018841
# kw_max_avg                          0.005688          0.002425
# kw_avg_avg                          0.001033          0.007895
# self_reference_min_shares          -0.003846         -0.023922
# self_reference_max_shares          -0.002236          0.024961
# self_reference_avg_sharess         -0.001039         -0.009625
# global_subjectivity                -0.041812          0.135791
# global_sentiment_polarity          -0.077688          0.015245
# global_rate_positive_words         -0.063576          0.126677
# global_rate_negative_words          0.031238          0.140095
# rate_positive_words                -0.067715          0.038846
# rate_negative_words                 0.051904          0.085084
# avg_positive_polarity              -0.034573          0.133996
# min_positive_polarity              -0.006471         -0.278710
# max_positive_polarity              -0.009682          0.419922
# avg_negative_polarity              -0.039632         -0.142622
# min_negative_polarity              -0.046665         -0.462047
# max_negative_polarity               0.000484          0.245554
# title_subjectivity                  0.096116          0.033486
# title_sentiment_polarity           -0.002754          0.030881
# abs_title_subjectivity             -0.156413         -0.002703
# abs_title_sentiment_polarity        0.052933          0.038008
# data_channel                       -0.021430          0.018176
#
#                               n_unique_tokens  n_non_stop_words  \
# n_tokens_title                      -0.004753         -0.004314
# n_tokens_content                    -0.005331          0.014529
# n_unique_tokens                      1.000000          0.999666
# n_non_stop_words                     0.999666          1.000000
# n_non_stop_unique_tokens             0.999908          0.999628
# num_hrefs                           -0.006150          0.003083
# num_self_hrefs                       0.005670          0.011774
# num_imgs                             0.022668          0.032085
# num_videos                          -0.001941         -0.001200
# average_token_length                 0.017741          0.020858
# num_keywords                        -0.004027         -0.001527
# kw_min_min                           0.000138         -0.001507
# kw_max_min                          -0.000861         -0.000645
# kw_avg_min                          -0.001454         -0.001373
# kw_min_max                           0.001630          0.001099
# kw_max_max                          -0.000136          0.001644
# kw_avg_max                           0.004502          0.003055
# kw_min_avg                           0.006973          0.006881
# kw_max_avg                          -0.002024         -0.002309
# kw_avg_avg                          -0.000356         -0.001068
# self_reference_min_shares            0.000207         -0.000262
# self_reference_max_shares           -0.001051         -0.000634
# self_reference_avg_sharess           0.001153          0.000948
# global_subjectivity                 -0.014504         -0.011702
# global_sentiment_polarity           -0.003674         -0.003483
# global_rate_positive_words          -0.008333         -0.006402
# global_rate_negative_words          -0.006835         -0.004332
# rate_positive_words                 -0.012066         -0.010727
# rate_negative_words                 -0.007275         -0.005055
# avg_positive_polarity               -0.012513         -0.010108
# min_positive_polarity                0.004135         -0.003738
# max_positive_polarity               -0.018843         -0.008681
# avg_negative_polarity                0.008674          0.005737
# min_negative_polarity                0.015257          0.004879
# max_negative_polarity               -0.003127          0.003167
# title_subjectivity                  -0.005159         -0.004954
# title_sentiment_polarity            -0.002658         -0.001718
# abs_title_subjectivity              -0.009920         -0.009687
# abs_title_sentiment_polarity        -0.004806         -0.004218
# data_channel                        -0.007395         -0.005357
#
#                               n_non_stop_unique_tokens  num_hrefs  \
# n_tokens_title                               -0.004873  -0.045392
# n_tokens_content                             -0.002319   0.465718
# n_unique_tokens                               0.999908  -0.006150
# n_non_stop_words                              0.999628   0.003083
# n_non_stop_unique_tokens                      1.000000  -0.006574
# num_hrefs                                    -0.006574   1.000000
# num_self_hrefs                                0.005633   0.402648
# num_imgs                                      0.018867   0.294920
# num_videos                                   -0.002290   0.120131
# average_token_length                          0.022855   0.177768
# num_keywords                                 -0.004363   0.131291
# kw_min_min                                    0.000156  -0.042017
# kw_max_min                                   -0.000846   0.013081
# kw_avg_min                                   -0.001348   0.007143
# kw_min_max                                    0.001487  -0.021278
# kw_max_max                                   -0.000095   0.052063
# kw_avg_max                                    0.004004  -0.040907
# kw_min_avg                                    0.006371   0.051680
# kw_max_avg                                   -0.002410   0.037884
# kw_avg_avg                                   -0.001230   0.078954
# self_reference_min_shares                     0.000295  -0.020290
# self_reference_max_shares                    -0.000946   0.052574
# self_reference_avg_sharess                    0.001239   0.003646
# global_subjectivity                          -0.010153   0.154943
# global_sentiment_polarity                    -0.002895   0.089794
# global_rate_positive_words                   -0.005251   0.073496
# global_rate_negative_words                   -0.004151   0.015469
# rate_positive_words                          -0.008971   0.078539
# rate_negative_words                          -0.005084   0.015595
# avg_positive_polarity                        -0.008834   0.145104
# min_positive_polarity                         0.003573  -0.151322
# max_positive_polarity                        -0.014320   0.275509
# avg_negative_polarity                         0.006023  -0.114743
# min_negative_polarity                         0.011208  -0.249235
# max_negative_polarity                        -0.002575   0.093829
# title_subjectivity                           -0.005542   0.036814
# title_sentiment_polarity                     -0.003220   0.046172
# abs_title_subjectivity                       -0.009439   0.002886
# abs_title_sentiment_polarity                 -0.005323   0.051809
# data_channel                                 -0.007139  -0.002504
#
#                               num_self_hrefs  num_imgs  num_videos  \
# n_tokens_title                     -0.013441  0.009149    0.061186
# n_tokens_content                    0.297179  0.401810    0.131991
# n_unique_tokens                     0.005670  0.022668   -0.001941
# n_non_stop_words                    0.011774  0.032085   -0.001200
# n_non_stop_unique_tokens            0.005633  0.018867   -0.002290
# num_hrefs                           0.402648  0.294920    0.120131
# num_self_hrefs                      1.000000  0.269273    0.066849
# num_imgs                            0.269273  1.000000   -0.034716
# num_videos                          0.066849 -0.034716    1.000000
# average_token_length                0.077918 -0.052371   -0.008523
# num_keywords                        0.105435  0.074687   -0.022910
# kw_min_min                         -0.018511 -0.029446   -0.024725
# kw_max_min                         -0.002817 -0.001162   -0.003798
# kw_avg_min                         -0.004791 -0.007121   -0.016822
# kw_min_max                         -0.019860 -0.000136    0.030920
# kw_max_max                          0.007070  0.036015    0.029923
# kw_avg_max                         -0.046331 -0.038582    0.098996
# kw_min_avg                          0.058735  0.058125    0.055650
# kw_max_avg                         -0.006055  0.027384    0.030832
# kw_avg_avg                          0.010056  0.073763    0.083943
# self_reference_min_shares          -0.030877 -0.008334   -0.005857
# self_reference_max_shares           0.113290  0.026409    0.045341
# self_reference_avg_sharess          0.020536  0.004320    0.021384
# global_subjectivity                 0.092645  0.012914    0.061259
# global_sentiment_polarity           0.096446  0.017257   -0.017553
# global_rate_positive_words          0.112029 -0.033126    0.075920
# global_rate_negative_words         -0.013983  0.002328    0.150520
# rate_positive_words                 0.120669 -0.042934   -0.033190
# rate_negative_words                -0.044671  0.003678    0.048831
# avg_positive_polarity               0.076844  0.045517    0.089755
# min_positive_polarity              -0.088082 -0.087398   -0.022333
# max_positive_polarity               0.167341  0.147369    0.113070
# avg_negative_polarity              -0.037117 -0.032213   -0.112788
# min_negative_polarity              -0.098916 -0.123975   -0.133970
# max_negative_polarity               0.054531  0.086320    0.031877
# title_subjectivity                 -0.006213  0.045800    0.060007
# title_sentiment_polarity            0.030553  0.055008    0.023677
# abs_title_subjectivity              0.005794 -0.018418   -0.029127
# abs_title_sentiment_polarity       -0.002604  0.055188    0.054434
# data_channel                        0.015210 -0.020546   -0.108481
#
#                               average_token_length  ...  \
# n_tokens_title                           -0.065099  ...
# n_tokens_content                          0.113963  ...
# n_unique_tokens                           0.017741  ...
# n_non_stop_words                          0.020858  ...
# n_non_stop_unique_tokens                  0.022855  ...
# num_hrefs                                 0.177768  ...
# num_self_hrefs                            0.077918  ...
# num_imgs                                 -0.052371  ...
# num_videos                               -0.008523  ...
# average_token_length                      1.000000  ...
# num_keywords                             -0.035682  ...
# kw_min_min                                0.015108  ...
# kw_max_min                               -0.004544  ...
# kw_avg_min                                0.002398  ...
# kw_min_max                               -0.004440  ...
# kw_max_max                               -0.018055  ...
# kw_avg_max                               -0.033464  ...
# kw_min_avg                               -0.026701  ...
# kw_max_avg                               -0.035747  ...
# kw_avg_avg                               -0.077003  ...
# self_reference_min_shares                 0.015117  ...
# self_reference_max_shares                 0.020200  ...
# self_reference_avg_sharess                0.020161  ...
# global_subjectivity                       0.452145  ...
# global_sentiment_polarity                 0.106615  ...
# global_rate_positive_words                0.214749  ...
# global_rate_negative_words                0.163081  ...
# rate_positive_words                       0.448583  ...
# rate_negative_words                       0.250201  ...
# avg_positive_polarity                     0.402406  ...
# min_positive_polarity                     0.148229  ...
# max_positive_polarity                     0.333124  ...
# avg_negative_polarity                    -0.233008  ...
# min_negative_polarity                    -0.194209  ...
# max_negative_polarity                    -0.141233  ...
# title_subjectivity                       -0.034634  ...
# title_sentiment_polarity                 -0.023385  ...
# abs_title_subjectivity                    0.024910  ...
# abs_title_sentiment_polarity             -0.042359  ...
# data_channel                              0.033071  ...
#
#                               min_positive_polarity  max_positive_polarity  \
# n_tokens_title                            -0.006471              -0.009682
# n_tokens_content                          -0.278710               0.419922
# n_unique_tokens                            0.004135              -0.018843
# n_non_stop_words                          -0.003738              -0.008681
# n_non_stop_unique_tokens                   0.003573              -0.014320
# num_hrefs                                 -0.151322               0.275509
# num_self_hrefs                            -0.088082               0.167341
# num_imgs                                  -0.087398               0.147369
# num_videos                                -0.022333               0.113070
# average_token_length                       0.148229               0.333124
# num_keywords                              -0.037859               0.070462
# kw_min_min                                 0.008497              -0.006411
# kw_max_min                                -0.001676               0.010531
# kw_avg_min                                -0.003329               0.015909
# kw_min_max                                 0.006756              -0.000532
# kw_max_max                                -0.010690               0.005158
# kw_avg_max                                 0.001869              -0.041595
# kw_min_avg                                 0.000266               0.020667
# kw_max_avg                                -0.007262               0.019760
# kw_avg_avg                                -0.004802               0.048224
# self_reference_min_shares                  0.009827              -0.012553
# self_reference_max_shares                 -0.016356               0.025133
# self_reference_avg_sharess                -0.001280               0.002918
# global_subjectivity                        0.141592               0.442408
# global_sentiment_polarity                  0.053840               0.428174
# global_rate_positive_words                -0.170372               0.445329
# global_rate_negative_words                 0.010906               0.130534
# rate_positive_words                       -0.000589               0.367268
# rate_negative_words                        0.152801              -0.063865
# avg_positive_polarity                      0.387934               0.657847
# min_positive_polarity                      1.000000              -0.074716
# max_positive_polarity                     -0.074716               1.000000
# avg_negative_polarity                      0.014111              -0.208433
# min_negative_polarity                      0.152416              -0.318829
# max_negative_polarity                     -0.146210               0.056024
# title_subjectivity                        -0.007815               0.068410
# title_sentiment_polarity                  -0.007135               0.085405
# abs_title_subjectivity                     0.018259              -0.033181
# abs_title_sentiment_polarity              -0.006090               0.096466
# data_channel                               0.014116              -0.116177
#
#                               avg_negative_polarity  min_negative_polarity  \
# n_tokens_title                            -0.039632              -0.046665
# n_tokens_content                          -0.142622              -0.462047
# n_unique_tokens                            0.008674               0.015257
# n_non_stop_words                           0.005737               0.004879
# n_non_stop_unique_tokens                   0.006023               0.011208
# num_hrefs                                 -0.114743              -0.249235
# num_self_hrefs                            -0.037117              -0.098916
# num_imgs                                  -0.032213              -0.123975
# num_videos                                -0.112788              -0.133970
# average_token_length                      -0.233008              -0.194209
# num_keywords                               0.033820              -0.003051
# kw_min_min                                 0.036300               0.070570
# kw_max_min                                -0.001648              -0.001325
# kw_avg_min                                 0.004540               0.009104
# kw_min_max                                -0.016593              -0.011808
# kw_max_max                                -0.037121              -0.075413
# kw_avg_max                                -0.037457              -0.016378
# kw_min_avg                                -0.031743              -0.025608
# kw_max_avg                                -0.036659              -0.024581
# kw_avg_avg                                -0.061906              -0.036992
# self_reference_min_shares                 -0.021535               0.002777
# self_reference_max_shares                 -0.038034              -0.031466
# self_reference_avg_sharess                -0.033612              -0.011043
# global_subjectivity                       -0.367812              -0.294731
# global_sentiment_polarity                  0.261222               0.306331
# global_rate_positive_words                -0.079557              -0.073929
# global_rate_negative_words                -0.317875              -0.466446
# rate_positive_words                        0.056993               0.189715
# rate_negative_words                       -0.298228              -0.414045
# avg_positive_polarity                     -0.190984              -0.171171
# min_positive_polarity                      0.014111               0.152416
# max_positive_polarity                     -0.208433              -0.318829
# avg_negative_polarity                      1.000000               0.736293
# min_negative_polarity                      0.736293               1.000000
# max_negative_polarity                      0.534980               0.024902
# title_subjectivity                        -0.074449              -0.066252
# title_sentiment_polarity                   0.086232               0.072158
# abs_title_subjectivity                    -0.007500              -0.007940
# abs_title_sentiment_polarity              -0.072209              -0.065599
# data_channel                               0.076170               0.002679
#
#                               max_negative_polarity  title_subjectivity  \
# n_tokens_title                             0.000484            0.096116
# n_tokens_content                           0.245554            0.033486
# n_unique_tokens                           -0.003127           -0.005159
# n_non_stop_words                           0.003167           -0.004954
# n_non_stop_unique_tokens                  -0.002575           -0.005542
# num_hrefs                                  0.093829            0.036814
# num_self_hrefs                             0.054531           -0.006213
# num_imgs                                   0.086320            0.045800
# num_videos                                 0.031877            0.060007
# average_token_length                      -0.141233           -0.034634
# num_keywords                               0.043164            0.012727
# kw_min_min                                -0.023913           -0.008331
# kw_max_min                                 0.002618            0.015983
# kw_avg_min                                -0.002778            0.011700
# kw_min_max                                -0.008745            0.010396
# kw_max_max                                 0.026274            0.007862
# kw_avg_max                                -0.026634            0.017659
# kw_min_avg                                -0.007438            0.023150
# kw_max_avg                                -0.015574            0.037733
# kw_avg_avg                                -0.028554            0.060775
# self_reference_min_shares                 -0.039301           -0.001251
# self_reference_max_shares                 -0.019451            0.012156
# self_reference_avg_sharess                -0.037151            0.004599
# global_subjectivity                       -0.147866            0.124657
# global_sentiment_polarity                 -0.030722            0.029459
# global_rate_positive_words                -0.029171            0.126375
# global_rate_negative_words                 0.126499            0.093017
# rate_positive_words                       -0.174915           -0.006102
# rate_negative_words                        0.069787           -0.005051
# avg_positive_polarity                     -0.071195            0.056431
# min_positive_polarity                     -0.146210           -0.007815
# max_positive_polarity                      0.056024            0.068410
# avg_negative_polarity                      0.534980           -0.074449
# min_negative_polarity                      0.024902           -0.066252
# max_negative_polarity                      1.000000           -0.002323
# title_subjectivity                        -0.002323            1.000000
# title_sentiment_polarity                   0.002749            0.243901
# abs_title_subjectivity                    -0.008840           -0.527004
# abs_title_sentiment_polarity              -0.001327            0.707422
# data_channel                               0.065959           -0.044509
#
#                               title_sentiment_polarity  \
# n_tokens_title                               -0.002754
# n_tokens_content                              0.030881
# n_unique_tokens                              -0.002658
# n_non_stop_words                             -0.001718
# n_non_stop_unique_tokens                     -0.003220
# num_hrefs                                     0.046172
# num_self_hrefs                                0.030553
# num_imgs                                      0.055008
# num_videos                                    0.023677
# average_token_length                         -0.023385
# num_keywords                                  0.034383
# kw_min_min                                    0.036001
# kw_max_min                                    0.011366
# kw_avg_min                                    0.014509
# kw_min_max                                    0.010448
# kw_max_max                                   -0.033756
# kw_avg_max                                   -0.016209
# kw_min_avg                                    0.029143
# kw_max_avg                                    0.021423
# kw_avg_avg                                    0.043096
# self_reference_min_shares                    -0.000770
# self_reference_max_shares                     0.004278
# self_reference_avg_sharess                    0.000361
# global_subjectivity                           0.045104
# global_sentiment_polarity                     0.241570
# global_rate_positive_words                    0.155502
# global_rate_negative_words                   -0.134604
# rate_positive_words                           0.160569
# rate_negative_words                          -0.191039
# avg_positive_polarity                         0.093682
# min_positive_polarity                        -0.007135
# max_positive_polarity                         0.085405
# avg_negative_polarity                         0.086232
# min_negative_polarity                         0.072158
# max_negative_polarity                         0.002749
# title_subjectivity                            0.243901
# title_sentiment_polarity                      1.000000
# abs_title_subjectivity                       -0.261152
# abs_title_sentiment_polarity                  0.429881
# data_channel                                 -0.046887
#
#                               abs_title_subjectivity  \
# n_tokens_title                             -0.156413
# n_tokens_content                           -0.002703
# n_unique_tokens                            -0.009920
# n_non_stop_words                           -0.009687
# n_non_stop_unique_tokens                   -0.009439
# num_hrefs                                   0.002886
# num_self_hrefs                              0.005794
# num_imgs                                   -0.018418
# num_videos                                 -0.029127
# average_token_length                        0.024910
# num_keywords                               -0.010070
# kw_min_min                                  0.008303
# kw_max_min                                  0.003356
# kw_avg_min                                  0.006317
# kw_min_max                                 -0.008525
# kw_max_max                                 -0.009841
# kw_avg_max                                 -0.017016
# kw_min_avg                                 -0.013801
# kw_max_avg                                 -0.012912
# kw_avg_avg                                 -0.024224
# self_reference_min_shares                  -0.000334
# self_reference_max_shares                  -0.007388
# self_reference_avg_sharess                 -0.003988
# global_subjectivity                        -0.015589
# global_sentiment_polarity                  -0.041294
# global_rate_positive_words                 -0.147186
# global_rate_negative_words                 -0.051996
# rate_positive_words                        -0.031507
# rate_negative_words                         0.046115
# avg_positive_polarity                       0.004799
# min_positive_polarity                       0.018259
# max_positive_polarity                      -0.033181
# avg_negative_polarity                      -0.007500
# min_negative_polarity                      -0.007940
# max_negative_polarity                      -0.008840
# title_subjectivity                         -0.527004
# title_sentiment_polarity                   -0.261152
# abs_title_subjectivity                      1.000000
# abs_title_sentiment_polarity               -0.437702
# data_channel                                0.055031
#
#                               abs_title_sentiment_polarity  data_channel
# n_tokens_title                                    0.052933     -0.021430
# n_tokens_content                                  0.038008      0.018176
# n_unique_tokens                                  -0.004806     -0.007395
# n_non_stop_words                                 -0.004218     -0.005357
# n_non_stop_unique_tokens                         -0.005323     -0.007139
# num_hrefs                                         0.051809     -0.002504
# num_self_hrefs                                   -0.002604      0.015210
# num_imgs                                          0.055188     -0.020546
# num_videos                                        0.054434     -0.108481
# average_token_length                             -0.042359      0.033071
# num_keywords                                      0.023910      0.163220
# kw_min_min                                        0.003563     -0.037872
# kw_max_min                                        0.017352      0.000675
# kw_avg_min                                        0.012662     -0.016238
# kw_min_max                                        0.013414     -0.080438
# kw_max_max                                       -0.002121      0.038991
# kw_avg_max                                        0.008429     -0.217547
# kw_min_avg                                        0.037966     -0.094840
# kw_max_avg                                        0.038676     -0.063985
# kw_avg_avg                                        0.068139     -0.182054
# self_reference_min_shares                        -0.002189      0.002513
# self_reference_max_shares                         0.005109     -0.016857
# self_reference_avg_sharess                        0.000649     -0.009448
# global_subjectivity                               0.093964     -0.103649
# global_sentiment_polarity                         0.082020     -0.134919
# global_rate_positive_words                        0.121255     -0.190501
# global_rate_negative_words                        0.055048     -0.017317
# rate_positive_words                               0.010622     -0.115941
# rate_negative_words                              -0.032962      0.109826
# avg_positive_polarity                             0.108989     -0.120231
# min_positive_polarity                            -0.006090      0.014116
# max_positive_polarity                             0.096466     -0.116177
# avg_negative_polarity                            -0.072209      0.076170
# min_negative_polarity                            -0.065599      0.002679
# max_negative_polarity                            -0.001327      0.065959
# title_subjectivity                                0.707422     -0.044509
# title_sentiment_polarity                          0.429881     -0.046887
# abs_title_subjectivity                           -0.437702      0.055031
# abs_title_sentiment_polarity                      1.000000     -0.048219
# data_channel                                     -0.048219      1.000000
#
# [40 rows x 40 columns]

# %% [markdown]
# ### Heatmap All

# %%
fig, ax = plt.subplots(layout="constrained")
fig.suptitle("Correlations of attributes", fontsize=12)
im = ax.imshow(corr_matrix, aspect="auto")
ax.set_xticks(np.arange(len(corr_matrix.columns)), labels=corr_matrix.columns, fontsize=6)
ax.set_yticks(np.arange(len(corr_matrix.index)), labels=corr_matrix.index, fontsize=6)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
plt.colobar()

# %% [markdown]
# ### Heatmap wiht correlations more than 0.7

# %%
threshold = 0.7
corr_matrix = corr_matrix[abs(corr_matrix) >= threshold]
corr_matrix = corr_matrix[abs(corr_matrix) != 1.0]
corr_matrix = corr_matrix.dropna(axis=1, how='all')
corr_matrix = corr_matrix.dropna(axis=0, how='all')
fig, ax = plt.subplots(layout="constrained")
fig.suptitle(f"Correlations of attributes (> {threshold})", fontsize=16)

im = ax.imshow(corr_matrix, aspect="auto")
ax.set_xticks(np.arange(len(corr_matrix.columns)), labels=corr_matrix.columns, fontsize=8)
ax.set_yticks(np.arange(len(corr_matrix.index)), labels=corr_matrix.index, fontsize=8)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
for i in range(corr_matrix.shape[0]):
    for j in range(corr_matrix.shape[1]):
        text = ax.text(j, i, round(corr_matrix.iloc[i, j]), 2, fontsize=4)
                       ha="center", va="center", color="w")
plt.show()
